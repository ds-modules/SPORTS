# %% [markdown]
# # Assignment #: Probability and Game Theory
#
# ## Introduction
#
# In this assignment we are going to review probability and asses how game theory plays a role in sporting events. Through an investigation of tennis serves, soccer penalty kicks and play choices in football we will see how game theory is an essential component of many sporting decisions

# %% [markdown]
# ### Topics Covered:
#  1.)We will review basic probability rules including Bayes' Theorem etc.
#
#  2.)We will learn about tree diagrams and their role in conditional probability
#
#  3.)We will explore Game theory and the concept of a zero-sum game

# %% [markdown]
# ### Dependencies

# %%
#Run this cell to set up your notebook
#commands for running notebook below

# %% [markdown]
# ## 1.) Probability Review
#
# ### Basic Probability Rules
#
# Addition Rule: P(A or B) = P(A) + P(B)
#
# Multiplacation Rule: P(A and B) = P(A) * P (B|A)
#
# Bayes Theorem: P(A|B) = (P(B|A) * P(A))/ P(B)

# %% [markdown]
# ### Probability Practice
#
# Picture a deck of cards: 52 total cards, 4 suits, 13 cards per suit, and 4 of each card

# %%
#Event A=drawing an ace
#Event B = Drawing a heart


#Pr[A]
a=...

#Pr[B]
b=..

#Pr[A|B]
AB=..

#Pr[B|A]
BA=...

#Probability of A and B, Drawing with replacment

AXB=...
# Out:
#   File "<ipython-input-3-3a3122b841ba>", line 8
#     b=..
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 2.) Tree Diagrams
#
# Sometimes, if there are sequential steps in a probability space or if there are a number of stages of classification for objects sampled, or if the probability of certain events is dependent on previous events it is often useful to represent the probability space in a tree diagram
#
# Important things to consider to when building tree diagrams:
#
#   1.) Clearly define the events
#
#   2.) Calculate the probability for the event not occuring: 1-Pr[event occuring]
#
#   3.) When calculating probabilities from the tree diagrams, make sure the denominator includes all possible scenarios
#
# #### Hockey Shooting Example--Tree Diagrams
#  In the below diagram, we break up the probabilites based on the scenario. We define the first event, P(goalie in net) and then use that to determine the P(shooting) or P(using decoy) and then given these conditional results we find the P(scoring)

# %% [markdown]
# ![Screen%20Shot%202017-10-24%20at%204.38.08%20PM.png](attachment:Screen%20Shot%202017-10-24%20at%204.38.08%20PM.png)

# %%
#Answer the following the questions using the tree diagram above

#Pr[scoring]=...

#Pr[scoring given the player uses a decoy]=...

#Pr[no score given the player does not use a decoy]...

# %% [markdown]
# ### Endgame Basketball--Tree Diagram
# Now its your turn! Imagine you are a coach of the Golden State Warriors, the game is tied  and there is only time for one last shot!
#
# Using the following probabilities:
#
#                                  Pr[making an open 2pt shot]= 63%
#                                  Pr[making an open 3pt shot]=50%
#                                  Pr[making a contested 2pt shot]=40%
#                                  Pr[making a contested 3pt shot]=25%
#                                  Pr[defense contesting a shot]=65%
#
# Draw your own tree diagram and calcualte the following probabilites:

# %%
#Pr[making a 2pt shot]
x2=...

#Pr[making a 3pt shot]
x3=...

#Pr[winning given the shot is open] **remember winning is the probability of making any shot
winning_open=...

#Pr[winning]
winning=...

#Pr[losing] **hint(winning is the opposite of losing)
losing=...


#What is the best play you should call, a 2pt play or a 3pt play and explain why
best play= "<replace this>"
# Out:
#   File "<ipython-input-2-54d2f3edc867>", line 18
#     best play= "<replace this>"
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 3.) Game Theory
#
# Game Theory is "the study of mathematical models of conflict and cooperation between intelligent rational decision-makers".
#
#
#
# ### Zero Sum game
#
# A zero-sum game is a mathematical representation of a situation in which each participant's gain or loss of utility is exactly balanced by the losses or gains of the utility of the other participants.
# See how this works in the tennis serve example below:

# %% [markdown]
# ### Tennis Serve Example
#
# Consider the following simplified model of tennis serves, where the server must decide which side to serve too and the reciever must guess which side the serve is coming from. If we assume the server always wins when the receiver guesses the wrong direction and the
# reciever always wins if he/she guesses the right direction, we get the following matrix:

# %% [markdown]
# ### Pay-off matrix for tennis serves
#
# As we can see in the below diagram, the tennis serve scenario can be viewed as a zero-sum game with each participant equally likely to win.

# %% [markdown]
# ![Screen%20Shot%202017-10-26%20at%202.40.22%20PM.png](attachment:Screen%20Shot%202017-10-26%20at%202.40.22%20PM.png)

# %% [markdown]
# Now assume we know the following probabilities:
#
# The server wins the point 85% of the time when they serve to the receiver's backhand and the receiver guesses wrongly
#
# The server wins the point 45% of the time when they serve to the receiver's backhand and the receiver guesses correctly
#
# The server wins the point 75% of the time when they serve to the receiver's forehand and the receiver guesses wrongly
#
# The server wins the point 25% of the time when they serve to the receiver's forehand and the receiver guesses correctly

# %%
#Calculate the payoffs for the following scenarios given the above probabilites

#hits to forehand and guesses backhand
payoff1=...

#hits to forehand and guesses forehand
payoff2=...

#hits to backhand and guesses forehand
payoff3=...

#hits to backhand and guesses backhand
payoff4=...

# %% [markdown]
#  ## Goal Kick Problem
#
#  Pr[kickers kicks left]=
#
#  Pr[kicker kicks right]=
#
#  Pr[goalie guesses left]=
#
#  Pr[goalie guesses right]=
#
#  Create matrix without numbers filled in:

# %%
#which scenarios does the goalie win
goalie_wins

#which scenario does the kicker win
kicker_wins

#Why is this considered a zero-sum game
answer= "<replace this text>
"
# Out:
#   File "<ipython-input-4-0c6ab731adff>", line 8
#     answer= "<replace this text>
#                                 ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# ## Baseball Pitch Selection
#
# [needs the most work]
